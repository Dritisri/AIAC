# %% [markdown]
# <a href="https://colab.research.google.com/github/Dritisri/AIAC/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 1**:Use Google Gemini in Colab to write a Python function that reads a list of numbers and calculates the mean, minimum, and maximum values.

# %% [markdown]
# Prompt : Write a python program that reads a list of numbers and calculates the mean , mininmum and maximum

# %%
def analyze_numbers(numbers):
  """
  Calculates the mean, minimum, and maximum of a list of numbers.

  Args:
    numbers: A list of numbers.

  Returns:
    A tuple containing the mean, minimum, and maximum values.
    Returns None if the input list is empty.
  """
  if not numbers:
    return None

  mean = sum(numbers) / len(numbers)
  minimum = min(numbers)
  maximum = max(numbers)

  return mean, minimum, maximum

# Example usage:
my_list = [10, 20, 30, 40, 50]
mean_val, min_val, max_val = analyze_numbers(my_list)

if mean_val is not None:
  print(f"List: {my_list}")
  print(f"Mean: {mean_val}")
  print(f"Minimum: {min_val}")
  print(f"Maximum: {max_val}")
else:
  print("The list is empty.")

my_empty_list = []
result_empty = analyze_numbers(my_empty_list)

if result_empty is None:
  print("\nResult for empty list: The list is empty.")
# Out:
# List: [10, 20, 30, 40, 50]
# Mean: 30.0
# Minimum: 10
# Maximum: 50
#
# Result for empty list: The list is empty.

# %% [markdown]
# EXPLANATION OF THE CODE : The analyze_numbers function is a Python program that performs basic statistical analysis on a list of numbers. It calculates and returns the mean (average), minimum, and maximum values of the list. The function first checks if the list is empty to avoid errors; if it is, it returns None. Otherwise, it computes the required values using built-in functions (sum, min, and max) and returns them as a tuple. This function is useful for quickly analyzing numeric data, and the example usage demonstrates how it handles both non-empty and empty lists.

# %% [markdown]
# **TASK 2**: Compare Gemini and Copilot outputs for a Python function that checks whether a number is an Armstrong number. Document the steps, prompts, and outputs.

# %% [markdown]
# Prompt : Develop a python program that checks whether a number is an armstrong number

# %%
def is_armstrong_number(number):
  """
  Checks if a number is an Armstrong number.

  Args:
    number: An integer.

  Returns:
    True if the number is an Armstrong number, False otherwise.
  """
  # Convert the number to a string to get the number of digits
  num_str = str(number)
  num_digits = len(num_str)
  sum_of_powers = 0
  temp_number = number

  # Calculate the sum of the digits raised to the power of the number of digits
  while temp_number > 0:
    digit = temp_number % 10
    sum_of_powers += digit ** num_digits
    temp_number //= 10

  # Check if the sum is equal to the original number
  return sum_of_powers == number

# Example usage:
num1 = 153
if is_armstrong_number(num1):
  print(f"{num1} is an Armstrong number.")
else:
  print(f"{num1} is not an Armstrong number.")

num2 = 123
if is_armstrong_number(num2):
  print(f"{num2} is an Armstrong number.")
else:
  print(f"{num2} is not an Armstrong number.")
# Out:
# 153 is an Armstrong number.
# 123 is not an Armstrong number.

# %% [markdown]
# EXPLANATION:
# The is_armstrong_number function checks whether a given integer is an **Armstrong number**—a number that is equal to the sum of its own digits each raised to the power of the number of digits. The function converts the number to a string to determine how many digits it has, then uses a while loop to extract each digit, raise it to the appropriate power, and accumulate the result. Finally, it compares this sum to the original number and returns True if they match, indicating it's an Armstrong number, or False otherwise. Example checks with 153 (which is an Armstrong number) and 123 (which is not) demonstrate the function's correctness.

# %% [markdown]
# ![Screenshot 2025-08-12 115039.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-08-12 114650.png](data:image/png;base64,...)

# %% [markdown]
# OBSERVATION:
# COPILOT:
# Approach: Compact and efficient using Pythonic one-liner with sum() and a list comprehension.
#
# Style: Focuses on code brevity and performance.
#
# User Interaction: Takes dynamic input using input() inside the if __name__ == "__main__" block, making it suitable for real-time user input.
#
# Best For: Experienced programmers or production-ready scripts.
#
# GEMINI AI:
# Approach: Step-by-step using a while loop and manual digit extraction.
#
# Style: Emphasizes readability and explanation, with comments and docstrings.
#
# User Interaction: Uses hardcoded test values (153, 123) instead of dynamic input—better for demonstrations or tutorials.
#
# Best For: Beginners or educational purposes.
#
# *  Copilot prioritizes concise, production-ready code, while
# Gemini focuses on clarity and learning, making it easier for new programmers to follow the logic.

# %% [markdown]
# **TASK3**: Ask Gemini to explain a Python function (e.g., is_prime(n) or is_palindrome(s)) line by line.
# Choose either a prime-checking or palindrome-checking function and document the explanation provided by Gemini.

# %% [markdown]
# Prompt : Write a python progarm to choose either a prime-checking or palindrome-checking function

# %%
def is_prime(n):
  """
  Checks if a number is prime.

  Args:
    n: An integer.

  Returns:
    True if the number is prime, False otherwise.
  """
  if n <= 1:
    return False
  for i in range(2, int(n**0.5) + 1):
    if n % i == 0:
      return False
  return True

def is_palindrome(s):
  """
  Checks if a string is a palindrome.

  Args:
    s: A string.

  Returns:
    True if the string is a palindrome, False otherwise.
  """
  s = s.lower().replace(" ", "") # Convert to lowercase and remove spaces
  return s == s[::-1]

# --- User Interaction ---

choice = input("Enter 'prime' to check for prime or 'palindrome' to check for palindrome: ").lower()

if choice == 'prime':
  try:
    num = int(input("Enter an integer to check if it's prime: "))
    if is_prime(num):
      print(f"{num} is a prime number.")
    else:
      print(f"{num} is not a prime number.")
  except ValueError:
    print("Invalid input. Please enter an integer.")

elif choice == 'palindrome':
  text = input("Enter a string to check if it's a palindrome: ")
  if is_palindrome(text):
    print(f"'{text}' is a palindrome.")
  else:
    print(f"'{text}' is not a palindrome.")

else:
  print("Invalid choice. Please enter 'prime' or 'palindrome'.")
# Out:
# Enter 'prime' to check for prime or 'palindrome' to check for palindrome: palindrome
# Enter a string to check if it's a palindrome: 23
# '23' is not a palindrome.

# %% [markdown]
# EXPLANATION : This Python program allows the user to check whether a number is **prime** or a string is a **palindrome**. It includes two functions: is_prime() checks if a number is divisible only by 1 and itself using an efficient loop up to the square root of the number, while is_palindrome() checks if a string reads the same backward by reversing it after converting it to lowercase and removing spaces. The program prompts the user to choose between the two checks, takes appropriate input, and displays the result. It also includes basic input validation for robustness.

# %% [markdown]
# **TASK4** : Install and configure Cursor AI. Use it to generate a Python function (e.g., sum of the first N natural numbers) and test its output.
# Optionally, compare Cursor AI’s generated code with Gemini’s output.

# %% [markdown]
# Prompt : Write a pyhton program to generate a pyhton function of sum of the N natural numbers and test and with input values

# %%
def sum_of_natural_numbers(n):
  """
  Calculates the sum of the first N natural numbers.

  Args:
    n: A positive integer.

  Returns:
    The sum of the first N natural numbers.
    Returns None if n is not a positive integer.
  """
  if not isinstance(n, int) or n <= 0:
    return None
  return n * (n + 1) // 2

# Example usage:
n1 = 10
sum1 = sum_of_natural_numbers(n1)
if sum1 is not None:
  print(f"The sum of the first {n1} natural numbers is: {sum1}")
else:
  print(f"Invalid input: {n1}. Please enter a positive integer.")

n2 = 5
sum2 = sum_of_natural_numbers(n2)
if sum2 is not None:
  print(f"The sum of the first {n2} natural numbers is: {sum2}")
else:
  print(f"Invalid input: {n2}. Please enter a positive integer.")

n3 = -5
sum3 = sum_of_natural_numbers(n3)
if sum3 is not None:
  print(f"The sum of the first {n3} natural numbers is: {sum3}")
else:
  print(f"Invalid input: {n3}. Please enter a positive integer.")

n4 = 0
sum4 = sum_of_natural_numbers(n4)
if sum4 is not None:
  print(f"The sum of the first {n4} natural numbers is: {sum4}")
else:
  print(f"Invalid input: {n4}. Please enter a positive integer.")
# Out:
# The sum of the first 10 natural numbers is: 55
# The sum of the first 5 natural numbers is: 15
# Invalid input: -5. Please enter a positive integer.
# Invalid input: 0. Please enter a positive integer.

# %% [markdown]
# EXPLANATION : This Python program defines a function sum_of_natural_numbers(n) that calculates the sum of the first N natural numbers using the formula n * (n + 1) // 2. It first checks if the input is a positive integer; if not, it returns None. The program includes multiple test cases with different values (10, 5, -5, 0) to demonstrate valid and invalid inputs, printing appropriate messages for each. This ensures both correctness and input validation in a clean and efficient way.

# %% [markdown]
# **TASK 5**: Students need to write a Python program to calculate the sum of odd numbers and even numbers in a given tuple.
# Refactor the code to improve logic and readability.

# %% [markdown]
# Prompt : Write a python program to calculate the sum of odd numbers and even numbers in a given tuple and refactor the code to improve logic and readability with input values

# %%
def sum_odd_even(numbers_tuple):
  """
  Calculates the sum of odd and even numbers in a tuple.

  Args:
    numbers_tuple: A tuple of numbers.

  Returns:
    A tuple containing the sum of odd numbers and the sum of even numbers.
  """
  sum_odd = 0
  sum_even = 0
  for number in numbers_tuple:
    if isinstance(number, (int, float)): # Check if the element is a number
      if number % 2 == 0:
        sum_even += number
      else:
        sum_odd += number
    else:
      print(f"Warning: Skipping non-numeric element: {number}") # Handle non-numeric elements
  return sum_odd, sum_even

# Get input from the user
input_str = input("Enter numbers separated by commas (e.g., 1,2,3,4,5): ")
try:
  # Convert the input string into a tuple of numbers
  input_list = [float(x.strip()) for x in input_str.split(',')]
  input_tuple = tuple(input_list)

  odd_sum, even_sum = sum_odd_even(input_tuple)

  print(f"Given tuple: {input_tuple}")
  print(f"Sum of odd numbers: {odd_sum}")
  print(f"Sum of even numbers: {even_sum}")

except ValueError:
  print("Invalid input. Please enter numbers separated by commas.")
# Out:
# Enter numbers separated by commas (e.g., 1,2,3,4,5): 4,8,9,6,7
# Given tuple: (4.0, 8.0, 9.0, 6.0, 7.0)
# Sum of odd numbers: 16.0
# Sum of even numbers: 18.0

# %% [markdown]
# EXPLANATION : This program calculates the sum of odd and even numbers from a user-provided tuple. It takes a comma-separated string of numbers as input, converts it into a tuple of floats, and then processes each element to check if it’s numeric. The function sum_odd_even adds up all even numbers and odd numbers separately, while skipping and warning about any non-numeric elements. Finally, it prints the original tuple along with the sums of odd and even numbers. The code also includes error handling for invalid inputs to ensure robust user interaction.
